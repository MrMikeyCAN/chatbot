# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
with open("text.txt", "r", encoding="utf-8") as myfile:
    mytext = myfile.read()


mytokenizer = Tokenizer()
mytokenizer.fit_on_texts([mytext])
total_words = len(mytokenizer.word_index) + 1
mytokenizer.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'india': 3,
#  'in': 4,
#  'a': 5,
#  'and': 6,
#  'of': 7,
#  "'s": 8,
#  'n': 9,
#  'mr': 10,
#  'modi': 11,
#  'us': 12,
#  'is': 13,
#  'has': 14,
#  'that': 15,
#  'biden': 16,
#  'washington': 17,
#  'it': 18,
#  'as': 19,
#  'with': 20,
#  'not': 21,
#  'for': 22,
#  'on': 23,
#  'an': 24,
#  'says': 25,
#  'will': 26,
#  'are': 27,
#  'visit': 28,
#  'indian': 29,
#  'prime': 30,
#  'minister': 31,
#  'nthe': 32,
#  'china': 33,
#  'have': 34,
#  'trade': 35,
#  'by': 36,
#  'relationship': 37,
#  'this': 38,
#  'been': 39,
#  'about': 40,
#  'strategic': 41,
#  'president': 42,
#  'more': 43,
#  'up': 44,
#  'during': 45,
#  'also': 46,
#  'make': 47,
#  'sirohi': 48,
#  'nbut': 49,
#  'air': 50,
#  'force': 51,
#  'they': 52,
#  'state': 53,
#  'his': 54,
#  'world': 55,
#  'ties': 56,
#  'two': 57,
#  'at': 58,
#  'white': 59,
#  'house': 60,
#  'be': 61,
#  'lot': 62,
#  'technology': 63,
#  'jet': 64,
#  'but': 65,
#  'semiconductor': 66,
#  'now': 67,
#  'first': 68,
#  '2023': 69,
#  'administration': 70,
#  'was': 71,
#  'global': 72,
#  'one': 73,
#  'he': 74,
#  'without': 75,
#  'narendra': 76,
#  'joe': 77,
#  'country': 78,
#  'potential': 79,
#  'how': 80,
#  'become': 81,
#  'kugelman': 82,
#  'years': 83,
#  'there': 84,
#  'fighter': 85,
#  'nindia': 86,
#  'from': 87,
#  'which': 88,
#  'russia': 89,
#  'sides': 90,
#  'ms': 91,
#  'seen': 92,
#  'under': 93,
#  'or': 94,
#  'way': 95,
#  'policy': 96,
#  'partner': 97,
#  'autonomy': 98,
#  'didn': 99,
#  "'t": 100,
#  'could': 101,
#  'joint': 102,
#  'major': 103,
#  'following': 104,
#  'partnership': 105,
#  'most': 106,
#  'strengthening': 107,
#  'between': 108,
#  'nations': 109,
#  'closer': 110,
#  'than': 111,
#  'time': 112,
#  'said': 113,
#  'may': 114,
#  'broad': 115,
#  'reason': 116,
#  'can': 117,
#  'indo': 118,
#  'pacific': 119,
#  'had': 120,
#  'because': 121,
#  'later': 122,
#  'purchase': 123,
#  'former': 124,
#  'owned': 125,
#  'only': 126,
#  'wants': 127,
#  'arms': 128,
#  'sharing': 129,
#  'military': 130,
#  'drones': 131,
#  'facility': 132,
#  'into': 133,
#  "'": 134,
#  'biggest': 135,
#  'nmr': 136,
#  'invest': 137,
#  'test': 138,
#  'nus': 139,
#  'maker': 140,
#  'research': 141,
#  'all': 142,
#  'future': 143,
#  'u': 144,
#  's': 145,
#  'welcome': 146,
#  'june': 147,
#  'dc': 148,
#  'never': 149,
#  'place': 150,
#  'foreign': 151,
#  'wanted': 152,
#  'other': 153,
#  'what': 154,
#  'relations': 155,
#  'close': 156,
#  'obama': 157,
#  'trump': 158,
#  'further': 159,
#  'did': 160,
#  'importance': 161,
#  'free': 162,
#  'united': 163,
#  'states': 164,
#  'usaf': 165,
#  'personnel': 166,
#  'front': 167,
#  'april': 168,
#  'full': 169,
#  'over': 170,
#  'tariffs': 171,
#  'were': 172,
#  'discussions': 173,
#  'disputes': 174,
#  'democratic': 175,
#  'hindu': 176,
#  'party': 177,
#  'mutual': 178,
#  'lavish': 179,
#  'called': 180,
#  'among': 181,
#  'consequential': 182,
#  'bbc': 183,
#  'vikas': 184,
#  'pandey': 185,
#  'soutik': 186,
#  'biswas': 187,
#  'explore': 188,
#  'factors': 189,
#  'contribute': 190,
#  'populous': 191,
#  'stronger': 192,
#  'dynamic': 193,
#  'any': 194,
#  'history': 195,
#  'completion': 196,
#  'pomp': 197,
#  'filled': 198,
#  'remark': 199,
#  'exaggeration': 200,
#  'summit': 201,
#  'suggests': 202,
#  'transformed': 203,
#  'underscores': 204,
#  'just': 205,
#  'deep': 206,
#  'relatively': 207,
#  'short': 208,
#  'michael': 209,
#  'wilson': 210,
#  'center': 211,
#  'american': 212,
#  'think': 213,
#  'tank': 214,
#  'na': 215,
#  'key': 216,
#  'keen': 217,
#  'draw': 218,
#  'so': 219,
#  'act': 220,
#  'counterbalance': 221,
#  'growing': 222,
#  'influence': 223,
#  'lived': 224,
#  'their': 225,
#  'promise': 226,
#  'landmark': 227,
#  'civilian': 228,
#  'nuclear': 229,
#  'deal': 230,
#  '2005': 231,
#  'liability': 232,
#  'law': 233,
#  'passed': 234,
#  'three': 235,
#  'hobbled': 236,
#  'reactors': 237,
#  'followed': 238,
#  'fading': 239,
#  'commitment': 240,
#  'manmohan': 241,
#  'singh': 242,
#  'second': 243,
#  'term': 244,
#  'leader': 245,
#  'coalition': 246,
#  'government': 247,
#  'enthusiasm': 248,
#  'embracing': 249,
#  'given': 250,
#  'overall': 251,
#  'directive': 252,
#  'work': 253,
#  'seema': 254,
#  'author': 255,
#  'friends': 256,
#  'benefits': 257,
#  'story': 258,
#  'nms': 259,
#  'put': 260,
#  'effort': 261,
#  'substantive': 262,
#  'deliverables': 263,
#  'defence': 264,
#  'industrial': 265,
#  'cooperation': 266,
#  'topped': 267,
#  'list': 268,
#  'consider': 269,
#  'ngeneral': 270,
#  'electric': 271,
#  'hindustan': 272,
#  'aeronautics': 273,
#  'limited': 274,
#  'advanced': 275,
#  'engines': 276,
#  'indigenous': 277,
#  'light': 278,
#  'combat': 279,
#  'aircraft': 280,
#  'means': 281,
#  'greater': 282,
#  'transfer': 283,
#  'engine': 284,
#  'ever': 285,
#  'before': 286,
#  'clear': 287,
#  'sign': 288,
#  'sell': 289,
#  'comfortable': 290,
#  'proceed': 291,
#  '3bn': 292,
#  'battle': 293,
#  'tested': 294,
#  'mq': 295,
#  '9b': 296,
#  'predator': 297,
#  'general': 298,
#  'atomics': 299,
#  'set': 300,
#  'assembled': 301,
#  'fits': 302,
#  "'make": 303,
#  'campaign': 304,
#  'supplies': 305,
#  '11': 306,
#  '45': 307,
#  'supplier': 308,
#  'hopes': 309,
#  'primary': 310,
#  'provider': 311,
#  'coming': 312,
#  'immediate': 313,
#  'goal': 314,
#  'strengthen': 315,
#  'capacity': 316,
#  'counter': 317,
#  'base': 318,
#  'memory': 319,
#  'chip': 320,
#  'giant': 321,
#  'micron': 322,
#  '825m': 323,
#  'build': 324,
#  'assembly': 325,
#  'creating': 326,
#  'thousands': 327,
#  'jobs': 328,
#  'equipment': 329,
#  'lam': 330,
#  'train': 331,
#  '60': 332,
#  '000': 333,
#  'engineers': 334,
#  'through': 335,
#  'network': 336,
#  'interconnected': 337,
#  'labs': 338,
#  'centres': 339,
#  'speed': 340,
#  'education': 341,
#  'workforce': 342,
#  'development': 343,
#  'applied': 344,
#  'materials': 345,
#  'machines': 346,
#  'producing': 347,
#  'semiconductors': 348,
#  '400m': 349,
#  'establish': 350,
#  'engineering': 351,
#  'centre': 352,
#  'both': 353,
#  'talking': 354,
#  'cutting': 355,
#  'edge': 356,
#  'technologies': 357,
#  'seed': 358,
#  'shape': 359,
#  'lady': 360,
#  'jill': 361,
#  '21': 362,
#  'mrs': 363,
#  'many': 364,
#  'ups': 365,
#  'downs': 366,
#  'since': 367,
#  'seriously': 368,
#  'began': 369,
#  'courting': 370,
#  'bill': 371,
#  'clinton': 372,
#  'then': 373,
#  'george': 374,
#  'bush': 375,
#  'response': 376,
#  'measured': 377,
#  'overeager': 378,
#  'too': 379,
#  'forthcoming': 380,
#  'saw': 381,
#  'geopolitics': 382,
#  'its': 383,
#  'own': 384,
#  'order': 385,
#  'strategy': 386,
#  'nonalignment': 387,
#  'started': 388,
#  'jawaharlal': 389,
#  'nehru': 390,
#  'always': 391,
#  'deeply': 392,
#  'rooted': 393,
#  'camp': 394,
#  'junior': 395,
#  'superpower': 396,
#  'left': 397,
#  'ideals': 398,
#  'some': 399,
#  'describe': 400,
#  'altruism': 401,
#  'leading': 402,
#  'different': 403,
#  'kind': 404,
#  'considerably': 405,
#  'economic': 406,
#  'geopolitical': 407,
#  'heft': 408,
#  'formed': 409,
#  'bonds': 410,
#  'presidents': 411,
#  'barack': 412,
#  'donald': 413,
#  'sacrificed': 414,
#  'would': 415,
#  'go': 416,
#  'step': 417,
#  'probably': 418,
#  'take': 419,
#  'harder': 420,
#  'public': 421,
#  'stand': 422,
#  'seem': 423,
#  'disappointed': 424,
#  'repeated': 425,
#  'line': 426,
#  'era': 427,
#  'war': 428,
#  'mentioning': 429,
#  'speak': 430,
#  'beefing': 431,
#  'humanitarian': 432,
#  'assistance': 433,
#  'ukraine': 434,
#  'mention': 435,
#  'name': 436,
#  'either': 437,
#  'talk': 438,
#  'prosperous': 439,
#  'nthis': 440,
#  'far': 441,
#  'pushed': 442,
#  'compromising': 443,
#  'ideal': 444,
#  'come': 445,
#  'making': 446,
#  'success': 447,
#  'iaf': 448,
#  'posing': 449,
#  'f': 450,
#  '15': 451,
#  'eagle': 452,
#  "'exercise": 453,
#  'cope': 454,
#  'station': 455,
#  'kalaikunda': 456,
#  'around': 457,
#  '170': 458,
#  'km': 459,
#  'west': 460,
#  'kolkata': 461,
#  '24th': 462,
#  'pose': 463,
#  'exercise': 464,
#  'militaries': 465,
#  'working': 466,
#  'closely': 467,
#  'together': 468,
#  'arrangements': 469,
#  'where': 470,
#  'use': 471,
#  'each': 472,
#  'facilities': 473,
#  'refuelling': 474,
#  'maintenance': 475,
#  'purposes': 476,
#  'holding': 477,
#  'exercises': 478,
#  "'re": 479,
#  'intelligence': 480,
#  'credit': 481,
#  'managing': 482,
#  'really': 483,
#  'limits': 484,
#  'sense': 485,
#  'getting': 486,
#  'you': 487,
#  'power': 488,
#  'signing': 489,
#  'fledged': 490,
#  'alliance': 491,
#  'differences': 492,
#  'recent': 493,
#  'particularly': 494,
#  'suffered': 495,
#  'expected': 496,
#  'announce': 497,
#  'anything': 498,
#  'understood': 499,
#  'continue': 500,
#  'overshadowing': 501,
#  'surprisingly': 502,
#  'announced': 503,
#  'six': 504,
#  'separate': 505,
#  'organization': 506,
#  'resolved': 507,
#  'including': 508,
#  'involved': 509,
#  'top': 510,
#  'trading': 511,
#  '130bn': 512,
#  'goods': 513,
#  'delhi': 514,
#  'eighth': 515,
#  'largest': 516,
#  'while': 517,
#  'these': 518,
#  'numbers': 519,
#  'impressive': 520,
#  'analysts': 521,
#  'policymakers': 522,
#  'feel': 523,
#  'huge': 524,
#  'untapped': 525,
#  'burgeoning': 526,
#  'market': 527,
#  'expanding': 528,
#  'middle': 529,
#  'class': 530,
#  'positioning': 531,
#  'itself': 532,
#  'alternative': 533,
#  'manufacturing': 534,
#  'hub': 535,
#  'npresident': 536,
#  'participate': 537,
#  'arrival': 538,
#  'ceremony': 539,
#  'south': 540,
#  'lawn': 541,
#  'thursday': 542,
#  '22': 543,
#  'invite': 544,
#  'official': 545,
#  'nsome': 546,
#  '2': 547,
#  '7': 548,
#  'million': 549,
#  'indians': 550,
#  'live': 551,
#  'nmany': 552,
#  'firms': 553,
#  'interested': 554,
#  'proposal': 555,
#  'look': 556,
#  'supply': 557,
#  'chain': 558,
#  'dominance': 559,
#  'context': 560,
#  'resolution': 561,
#  'give': 562,
#  'impetus': 563,
#  'unlocking': 564,
#  'even': 565,
#  'sky': 566,
#  'limit': 567,
#  'ncritics': 568,
#  'questioned': 569,
#  'backsliding': 570,
#  'nationalist': 571,
#  'bharatiya': 572,
#  'janata': 573,
#  'bjp': 574,
#  'television': 575,
#  'interview': 576,
#  'week': 577,
#  'emphasised': 578,
#  'significance': 579,
#  'addressing': 580,
#  'protection': 581,
#  'muslim': 582,
#  'minority': 583,
#  'predominantly': 584,
#  'progressives': 585,
#  'disturbed': 586,
#  'happening': 587,
#  'realists': 588,
#  'centrists': 589,
#  'factor': 590,
#  'whole': 591,
#  'bipartisan': 592,
#  'agreement': 593,
#  'deeper': 594,
#  'broader': 595,
#  'certainly': 596,
#  'moved': 597,
#  'next': 598,
#  'level': 599,
#  'need': 600,
#  'benefit': 601}

# %%
my_input_sequences = []
for line in mytext.split("\n"):
    # print(line)
    token_list = mytokenizer.texts_to_sequences([line])[0]
    # print(token_list)
    for i in range(1, len(token_list)):
        my_n_gram_sequence = token_list[: i + 1]
        # print(my_n_gram_sequence)
        my_input_sequences.append(my_n_gram_sequence)
        # print(input_sequences)
max_sequence_len = max([len(seq) for seq in my_input_sequences])
input_sequences = np.array(
    pad_sequences(my_input_sequences, maxlen=max_sequence_len, padding="pre")
)

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

y = np.array(tf.keras.utils.to_categorical(y, num_classes=total_words))


model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len - 1))
model.add(LSTM(150))
model.add(Dense(total_words, activation="softmax"))
print(model.summary())


model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1460, 100)         60200
#
#  lstm (LSTM)                 (None, 150)               150600
#
#  dense (Dense)               (None, 602)               90902
#
# =================================================================
# Total params: 301,702
# Trainable params: 301,702
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 2024-01-19 12:22:21.899707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-01-19 12:22:21.900404: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-01-19 12:22:21.900795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-01-19 12:22:21.941606: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-01-19 12:22:22.028711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-01-19 12:22:22.029265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-01-19 12:22:22.029890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-01-19 12:22:22.244760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-01-19 12:22:22.245541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-01-19 12:22:22.246130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 46/46 [==============================] - 43s 928ms/step - loss: 6.1471 - accuracy: 0.0452
# Epoch 2/100
# 46/46 [==============================] - 42s 920ms/step - loss: 5.7674 - accuracy: 0.0548
# Epoch 3/100
# 46/46 [==============================] - 42s 922ms/step - loss: 5.6857 - accuracy: 0.0548
# Epoch 4/100
# 46/46 [==============================] - 42s 923ms/step - loss: 5.6225 - accuracy: 0.0548
# Epoch 5/100
# 46/46 [==============================] - 42s 922ms/step - loss: 5.5318 - accuracy: 0.0548
# Epoch 6/100
#  5/46 [==>...........................] - ETA: 39s - loss: 5.1702 - accuracy: 0.0688

# %%
def nwp(input_text: str, predict_next_words: int) -> str:
    for _ in range(predict_next_words):
        token_list = mytokenizer.texts_to_sequences([input_text])[0]
        print(token_list)
        token_list = pad_sequences(
            [token_list], maxlen=max_sequence_len - 1, padding="pre"
        )
        predicted = np.argmax(model.predict(token_list), axis=-1)
        output_word = ""
        for word, index in mytokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        input_text += " " + output_word
        return input_text

# %%
print(nwp("Hello sir", 10))
